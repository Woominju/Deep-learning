# %% [markdown]
# <a href="https://colab.research.google.com/github/Woominju/Deep-learning/blob/main/smiling_face_non_smiling_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense


from google.colab import drive
drive.mount('/content/drive')


base_path = '/content/drive/My Drive/Deep learning with CNN/'


datagen = ImageDataGenerator(rescale=1./255)


train_generator = datagen.flow_from_directory(
    base_path,
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(train_generator, epochs=10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 1213 images belonging to 2 classes.
# Epoch 1/10
# 38/38 [==============================] - 130s 3s/step - loss: 0.6643 - accuracy: 0.5845
# Epoch 2/10
# 38/38 [==============================] - 8s 218ms/step - loss: 0.3797 - accuracy: 0.8508
# Epoch 3/10
# 38/38 [==============================] - 12s 311ms/step - loss: 0.2552 - accuracy: 0.9093
# Epoch 4/10
# 38/38 [==============================] - 10s 269ms/step - loss: 0.1909 - accuracy: 0.9349
# Epoch 5/10
# 38/38 [==============================] - 8s 221ms/step - loss: 0.1684 - accuracy: 0.9406
# Epoch 6/10
# 38/38 [==============================] - 11s 273ms/step - loss: 0.1212 - accuracy: 0.9662
# Epoch 7/10
# 38/38 [==============================] - 8s 218ms/step - loss: 0.0966 - accuracy: 0.9703
# Epoch 8/10
# ...

# %%
import os
import random
from skimage.io import imread, imshow
import matplotlib.pyplot as plt

smilehappy = '/content/drive/My Drive/Deep learning with CNN/smile/'
smile_images = os.listdir(smilehappy)

selected_smile_image = random.choice(smile_images)
smilesmile = os.path.join(smilehappy, selected_smile_image)


fig, ax = plt.subplots(figsize=(3, 3))
imshow(imread(smilesmile), ax=ax, interpolation='nearest')
ax.set_title('Smile')
plt.show()

# %%
import os
import random
from skimage.io import imread, imshow
import matplotlib.pyplot as plt

non_smilehappy = '/content/drive/My Drive/Deep learning with CNN/non_smile/'
non_smile_images = os.listdir(non_smilehappy)

selected_non_smile_image = random.choice(non_smile_images)
non_smilenon_smile = os.path.join(non_smilehappy, selected_non_smile_image)


fig, ax = plt.subplots(figsize=(3, 3))
imshow(imread(non_smilenon_smile), ax=ax, interpolation='nearest')
ax.set_title('non_smile')
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

from google.colab import drive
drive.mount('/content/drive')

base_path = '/content/drive/My Drive/Deep learning with CNN/'

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    base_path,
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Dense 레이어 변경

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(train_generator, epochs=10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 1213 images belonging to 2 classes.
# Epoch 1/10
# 38/38 [==============================] - 12s 266ms/step - loss: 0.5603 - accuracy: 0.7098
# Epoch 2/10
# 38/38 [==============================] - 12s 318ms/step - loss: 0.2262 - accuracy: 0.9167
# Epoch 3/10
# 38/38 [==============================] - 9s 227ms/step - loss: 0.1559 - accuracy: 0.9505
# Epoch 4/10
# 38/38 [==============================] - 12s 321ms/step - loss: 0.1314 - accuracy: 0.9547
# Epoch 5/10
# 38/38 [==============================] - 11s 282ms/step - loss: 0.1034 - accuracy: 0.9613
# Epoch 6/10
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0928 - accuracy: 0.9711
# Epoch 7/10
# 38/38 [==============================] - 12s 319ms/step - loss: 0.0792 - accuracy: 0.9786
# Epoch 8/10
# ...
